# %%
print(1)
# Out:
# 1

# %%
import pandas as pd
import numpy as np

# from google.colab import drive
# drive.mount('/content/gdrive')
# DATA_PATH = '/content/gdrive/MyDrive/REU/PROJECT/DATA/'
DATA_PATH = "/home/jovyan/work/ner_congressional_records/DATA/"

# %%
mi_annotated = pd.read_csv(DATA_PATH+"mi_annotated_data.csv")
mn_annotated = pd.read_csv(DATA_PATH+"mn_annotated_data.csv")

# %%
mi_annotated
# Out:
#       Unnamed: 0                                   merged_full_name  \
# 0           1667  butzel long pac butzel long political action c...
# 1           1668  retired detroit police/fire assn pac retired d...
# 2           1669  committee to elect gene haymaker committee to ...
# 3           1670  jack coleman for state representativ jack cole...
# 4           1671  tuscola county republican party tuscola county...
# ...          ...                                                ...
# 2149     1954544  committee to elect jeremiah buffalo committee ...
# 2150     1954579                    jonathan hoover jonathan hoover
# 2151     1955959            miller for michigan miller for michigan
# 2152     1956014  southwest michigan building trades p southwest...
# 2153     1956999  douglas  waggener campaign committee douglas  ...
#
#      transactor_type
# 0       Organization
# 1       Organization
# 2       Organization
# 3       Organization
# 4       Organization
# ...

# %%
mn_annotated
# Out:
#        Unnamed: 0                    merged_full_name transactor_type
# 0             833                      rhode, peter s      Individual
# 1             834                      machayya, mark      Individual
# 2             835                       lovaasen, tim      Individual
# 3             836                          yang, adam      Individual
# 4             837                        elko, thomas      Individual
# ...           ...                                 ...             ...
# 74545      941633       young progressive majority mn    Organization
# 74546      944391      kaiser, jamie senate committee    Organization
# 74547      945886  cragg, daniel dist court committee    Organization
# 74548      948410    anderson, darrin house committee    Organization
# 74549      963047                               rypac    Organization
#
# [74550 rows x 3 columns]

# %%
annotated = mn_annotated[['merged_full_name', 'transactor_type']].copy()

# %%
annotated = pd.concat([mi_annotated, mn_annotated])

# %%
annotated
# Out:
#        Unnamed: 0                                   merged_full_name  \
# 0            1667  butzel long pac butzel long political action c...
# 1            1668  retired detroit police/fire assn pac retired d...
# 2            1669  committee to elect gene haymaker committee to ...
# 3            1670  jack coleman for state representativ jack cole...
# 4            1671  tuscola county republican party tuscola county...
# ...           ...                                                ...
# 74545      941633                      young progressive majority mn
# 74546      944391                     kaiser, jamie senate committee
# 74547      945886                 cragg, daniel dist court committee
# 74548      948410                   anderson, darrin house committee
# 74549      963047                                              rypac
#
#       transactor_type
# 0        Organization
# 1        Organization
# 2        Organization
# 3        Organization
# ...

# %%
annotated.to_csv(DATA_PATH+"mi_mn_annotated.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 annotated.to_csv(DATA_PATH+"mi_mn_annotated.csv")
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py:3902, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3891 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3893 formatter = DataFrameFormatter(
#    3894     frame=df,
#    3895     header=header,
#    (...)
#    3899     decimal=decimal,
#    3900 )
# -> 3902 return DataFrameRenderer(formatter).to_csv(
#    3903     path_or_buf,
#    3904     lineterminator=lineterminator,
#    3905     sep=sep,
#    3906     encoding=encoding,
#    3907     errors=errors,
# ...
