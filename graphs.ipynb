# %%
logistic_regresion = {
    "Name": "Logistic-Regression",
    "Accuracy": 97.0,
    "Recall": 63.0,
    "Precision": 87.0,
    "f1_score": 73.0
}

# %%
random_forest__tfidf_scores = {
    "Name": "Random-Forest-TFIDF",
    "Accuracy": 95.10268562401264,
    "Recall": 98.1294964028777,
    "Precision": 96.01126231816049,
    "f1_score": 97.05882352941177
}

# %%
DistilBert   = {
    "Name": "DistilBert  ",
    "Accuracy": 97.97530864197531,
    "Recall":99.23076923076923 ,
    "Precision":91.05882352941177 ,
    "f1_score": 94.96932515337423
}

# %%
random_forest__flag_scores = {
    "Name": "Random-Forest-FLAG",
    "Accuracy": 86.92733017377567,
    "Recall": 86.76258992805755,
    "Precision": 97.04935622317596,
    "f1_score": 91.618131172448782
}

# %%
random_forest__tfidf_scores
# Out:
# {'Name': 'Random-Forest-TFIDF',
#  'Accuracy': 95.10268562401264,
#  'Recall': 98.1294964028777,
#  'Precision': 96.01126231816049,
#  'f1_score': 97.05882352941177}

# %%
random_forest__flag_scores
# Out:
# {'Name': 'Random-Forest-FLAG',
#  'Accuracy': 86.92733017377567,
#  'Recall': 86.76258992805755,
#  'Precision': 97.04935622317596,
#  'f1_score': 91.61813117244878}

# %%
import pandas as pd

# %%
df = pd.DataFrame([
    random_forest__flag_scores, random_forest__tfidf_scores, DistilBert , logistic_regresion
])
df
# Out:
#                   Name   Accuracy     Recall  Precision   f1_score
# 0   Random-Forest-FLAG  86.927330  86.762590  97.049356  91.618131
# 1  Random-Forest-TFIDF  95.102686  98.129496  96.011262  97.058824
# 2         DistilBert    97.975309  99.230769  91.058824  94.969325
# 3  Logistic-Regression  97.000000  63.000000  87.000000  73.000000

# %%
# data from https://allisonhorst.github.io/palmerpenguins/

import matplotlib.pyplot as plt
import numpy as np

scores_names = ("Accuracy", "Recall", "Precision", "F1 score")



score_by_model = {
    
    "Random-Forest-FLAG": df[df['Name']=='Random-Forest-FLAG'][["Accuracy", "Recall", "Precision", "f1_score"]],
    "Random-Forest-TFIDF": df[df['Name']=='Random-Forest-TFIDF'][["Accuracy", "Recall", "Precision", "f1_score"]], 
    "DistilBert ": df[df['Name']=='DistilBert '][["Accuracy", "Recall", "Precision", "f1_score"]],
    "Logistic-Regression": df[df['Name']=='Logistic-Regression'][["Accuracy", "Recall", "Precision", "f1_score"]]  
    
}
score_by_model
# x = np.arange(len(scores_names))  # the label locations
# width = 0.25  # the width of the bars
# multiplier = 0

# fig, ax = plt.subplots(layout='constrained')

# for attribute, measurement in score_by_model.items():
#     offset = width * multiplier
#     rects = ax.bar(x + offset, measurement, width, label=attribute)
#     ax.bar_label(rects, padding=3)
#     multiplier += 1

# # Add some text for labels, title and custom x-axis tick labels, etc.
# ax.set_ylabel('Length (mm)')
# ax.set_title('Penguin attributes by species')
# ax.set_xticks(x + width, scores_names)
# ax.legend(loc='upper left', ncols=3)
# ax.set_ylim(0, 250)

# plt.show()
# Out:
# {'Random-Forest-FLAG':    Accuracy    Recall  Precision   f1_score
#  0  86.92733  86.76259  97.049356  91.618131,
#  'Random-Forest-TFIDF':     Accuracy     Recall  Precision   f1_score
#  1  95.102686  98.129496  96.011262  97.058824,
#  'DistilBert ': Empty DataFrame
#  Columns: [Accuracy, Recall, Precision, f1_score]
#  Index: [],
#  'Logistic-Regression':    Accuracy  Recall  Precision  f1_score
#  3      97.0    63.0       87.0      73.0}

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(4)
y1 = [logistic_regresion['Accuracy'], logistic_regresion['Recall'], logistic_regresion['Precision'], logistic_regresion['f1_score']]
y2 = [random_forest__tfidf_scores['Accuracy'], random_forest__tfidf_scores['Recall'], random_forest__tfidf_scores['Precision'], random_forest__tfidf_scores['f1_score']]
y3 = [random_forest__flag_scores['Accuracy'], random_forest__flag_scores['Recall'], random_forest__flag_scores['Precision'], random_forest__flag_scores['f1_score']]
y4 = [DistilBert ['Accuracy'], DistilBert ['Recall'], DistilBert ['Precision'], DistilBert ['f1_score']]

width = 0.2

# plot data in grouped manner of bar type
plt.bar(x-0.2, y1, width, color='blue')
plt.bar(x, y2, width, color='orange')
plt.bar(x+0.2, y3, width, color='green')
plt.bar(x+0.4, y4, width, color='gray')

plt.xticks(x, ['Accuracy', 'Recall', 'Precision', 'F1 Score'])
plt.xlabel("Metrics")
plt.ylabel("Scores")
plt.title("Score comparison for each model")
plt.legend(["Logistic Regression", "Random Forest TFIDF", "Random Forest FLAG", "DistilBert "], bbox_to_anchor=[1,1])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(3)
y1 = [0.98, 0.14, 0.91]
y2 = [0.94, 0.14, 0.88]
y3 = [0.93, 0.14, 0.86]
# y1 = [logistic_regresion['Accuracy'], logistic_regresion['Recall'], logistic_regresion['Precision'], logistic_regresion['f1_score']]
# y2 = [random_forest__tfidf_scores['Accuracy'], random_forest__tfidf_scores['Recall'], random_forest__tfidf_scores['Precision'], random_forest__tfidf_scores['f1_score']]
# y3 = [random_forest__flag_scores['Accuracy'], random_forest__flag_scores['Recall'], random_forest__flag_scores['Precision'], random_forest__flag_scores['f1_score']]
# y4 = [DistilBert ['Accuracy'], DistilBert ['Recall'], DistilBert ['Precision'], DistilBert ['f1_score']]

width = 0.2

# plot data in grouped manner of bar type
plt.bar(x-0.2, y1, width, color='#204463')
plt.bar(x, y2, width, color='#8b0000')
plt.bar(x+0.2, y3, width, color='#888888')
# plt.bar(x+0.4, y4, width, color='gray')

plt.xticks(x, ['test set pa-az', 'entire mi-mn dataset ', 'all states combine test set'])
plt.xlabel("Metrics")
plt.ylabel("F1-Score")
plt.title("Score comparison for each model")
plt.legend(["RoBERTa", "DistilBERT", "ALBERT"], bbox_to_anchor=[1,1])
plt.show()
